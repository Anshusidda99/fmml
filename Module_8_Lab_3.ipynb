# %% [markdown]
# <a href="https://colab.research.google.com/github/Anshusidda99/fmml/blob/main/Module_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-26 13:40:37--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   102MB/s    in 0.7s
#
# 2024-03-26 13:40:38 (102 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 24940  1501.01697v2  We propose a two-stage algorithm for the super...    cs
# 6210   1609.05772v1  This paper considers a restriction to non-nega...  stat
# 23052  1802.08167v1  We present the Causal Gaussian Process Convolu...  stat
# 2278   1712.10050v1  Under covariate shift, training (source) data ...    cs
# 30846  1801.06302v1  Modeling statistical regularities is the probl...    cs
# ...             ...                                                ...   ...
# 4979   1706.10240v2  The current paper proposes a novel variational...    cs
# 30703  1801.00879v1  In this paper, we have proposed a novel featur...    cs
# 5589    1309.1193v2  Our work is focused on the joint sparsity reco...  stat
# 13197   1102.0059v2  Recent advances in tissue microarray technolog...  stat
# 13781   1412.0307v1  Most experimental studies initialize the popul...    cs
#
#                                                    title  year  \
# 24940  Super-resolution MRI Using Finite Rate of Inno...  2015
# 6210                     Stochastic Matrix Factorization  2016
# 23052  Learning Causally-Generated Stationary Time Se...  2018
# 2278   Kernel Robust Bias-Aware Prediction under Cova...  2017
# 30846  Fully Point-wise Convolutional Neural Network ...  2018
# ...                                                  ...   ...
# 4979   Bridging the Gap between Probabilistic and Det...  2017
# 30703  A Novel Feature Descriptor for Image Retrieval...  2018
# 5589   Confidence-constrained joint sparsity recovery...  2013
# 13197  Statistical methods for tissue array images - ...  2011
# 13781  Seeding the Initial Population of Multi-Object...  2014
#
#                                                 keywords
# 24940  [algorithm, resolution, frequency, resolution,...
# 6210   [considers, restriction, factorization, stocha...
# 23052  [convolution, nonparametric, spectrally, dynam...
# 2278   [covariate, distribution, conditional, distrib...
# 30846  [statistical, regularities, representing, dist...
# ...                                                  ...
# 4979   [variational, predictive, fluctuated, exemplar...
# 30703  [descriptors, combining, information, collecti...
# 5589   [corrupted, formulate, confidence, constrained...
# 13197  [microarray, technology, immunohistochemistry,...
# 13781  [experimental, initialize, population, evoluti...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 24940    [algorithm, resolution, frequency, resolution,...
# 6210     [considers, restriction, factorization, stocha...
# 23052    [convolution, nonparametric, spectrally, dynam...
# 2278     [covariate, distribution, conditional, distrib...
# 30846    [statistical, regularities, representing, dist...
#                                ...
# 21586    [optimization, forecaster, represented, unders...
# 4782     [hierarchically, different, assigning, compone...
# 34709    [approaches, answering, developed, increased, ...
# 27539    [classifiers, privileged, information, specifi...
# 22401    [generalized, canonical, correlation, dimensio...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8725 words.
# Out of those 4563 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="cecd6125-ac88-43b4-af39-575f50b8b122" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cecd6125-ac88-43b4-af39-575f50b8b122")) {                    Plotly.newPlot(                        "cecd6125-ac88-43b4-af39-575f50b8b122",                        [{"x":["extensions","determine","resolution","analytical","noiseless","proposing","dimensional","algorithm","innovation","efficient","discretized","frequency","developing","extending","represent","variation","simulated","experiments","performance","independent","reconstructions","application","stochastic","analyzing","necessary","parameters","sufficient","estimator","illustrated","unstructured","conditions","abstracts","economics","restriction","considers","characterizes","consistent","factorization","retrieving","synthetic","generated","statistical","construction","convolution","variational","inferential","contributions","significantly","stationary","equivalent","nonparametric","phenomena","demonstrated","inference","modelling","dynamical","generative","distribution","constraints","challenging","classifier","employing","synthetically","conditional","insufficient","covariate","representer","predictions","regularized","demonstrate","expectation","guarantees","competing","reweighted","uncertainty","consistency","logarithmic","prediction","minimization","certainty","establish","available","regularities","applications","complexity","distributed","architectures","constancy","observation","computational","accordingly","architecture","underwater","representation","convolutions","identically","maintaining","processing","enhancement","representing","efficiently","convolutional","extremely","ensembles","distributions","achieving","comparable","popularity","increasing","community","introduced","labelling","correlated","cognitive","unsupervised","biomarkers","attracted","effective","procedure","impairment","classification","annotation","discriminative","resonance","knowledge","hippocampus","attention","alzheimers","treatment","identified","successfully","informative","extracted","typically","structures","representations","promising","extraction","diagnosis","supervised","improving","capability","different","decreasing","computation","accurately","diversity","artifacts","manipulating","occurrence","generators","principal","orientation","practical","advantages","structure","trajectory","estimation","numerically","exploiting","regression","smoothing","component","geodesics","operators","theoretical","filtering","translation","riemannian","projective","prescribed","intrinsic","adversarial","interpretation","transportation","preliminary","kantorovich","framework","calculates","especially","geometric","competition","relations","therefore","experimental","probability","constructing","outperforms","discriminator","potential","simplified","generator","approximating","confidence","reasoning","propositions","argumentation","statements","arguments","assignment"],"y":[44,63,123,23,2,23,184,840,4,435,4,70,59,28,130,58,69,599,865,136,16,234,125,59,72,268,72,24,22,21,128,4,4,6,36,8,75,42,12,128,180,179,57,44,56,4,48,264,27,53,19,27,104,226,50,23,122,244,152,267,139,41,6,112,9,2,2,91,48,568,30,87,20,6,100,51,25,210,56,11,52,306,12,445,214,110,107,5,69,315,12,223,3,353,10,6,36,298,33,74,193,358,45,15,117,85,91,28,109,67,128,10,32,51,137,4,27,226,135,6,497,46,98,21,344,1,168,8,36,50,95,36,95,102,141,212,117,123,48,175,121,52,685,8,159,53,34,28,5,32,6,30,25,118,98,330,31,224,21,73,118,23,117,1,47,141,65,112,15,5,5,42,114,52,13,46,1,540,4,116,69,26,80,160,379,201,36,254,13,164,20,35,18,41,147,10,15,15,15,38],"type":"bar"},{"x":["extensions","determine","resolution","analytical","noiseless","proposing","dime ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4563,), (4563, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.785

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.4761904761904761);'>Development</span> <span style=''>of</span> <span style=''>YesNo</span> <span style=''>Arabic</span> <span style=''>Question</span> <span style='background-color:rgba(0, 255, 0, 0.7735849056603774);'>Answering</span> <span style=''>System</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.388235294117647);'>Developing</span> <span style=''>Question</span> <span style='background-color:rgba(0, 255, 0, 0.7735849056603774);'>Answering</span> <span style=''>systems</span> <span style=''>has</span> <span style=''>been</span> <span style=''>one</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>important</span> <span style=''>research</span> <span style=''>issues</span> <span style=''>because</span> <span style=''>it</span> <span style=''>requires</span> <span style=''>insights</span> <span style=''>from</span> <span style=''>a</span> <span style=''>variety</span> <span style=''>of</span> <span style=''>disciplinesincludingArtificial</span> <span style=''>IntelligenceInformation</span> <span style='background-color:rgba(0, 255, 0, 0.62406015037594);'>Retrieval</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Information</span> <span style=''>ExtractionNatural</span> <span style=''>Language</span> <span style='background-color:rgba(0, 255, 0, 0.46437346437346433);'>Processing</span> <span style=''>and</span> <span style=''>PsychologyIn</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>realize</span> <span style=''>a</span> <span style=''>formal</span> <span style=''>model</span> <span style=''>for</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>lightweight</span> <span style=''>semantic</span> <span style=''>based</span> <span style=''>open</span> <span style=''>domain</span> <span style=''>yesno</span> <span style=''>Arabic</span> <span style=''>question</span> <span style='background-color:rgba(0, 255, 0, 0.7735849056603774);'>answering</span> <span style=''>system</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.6);'>paragraph</span> <span style='background-color:rgba(0, 255, 0, 0.62406015037594);'>retrieval</span> <span style=''>with</span> <span style=''>variable</span> <span style=''>length</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constrained</span> <span style=''>semantic</span> <span style='background-color:rgba(0, 255, 0, 0.387033398821218);'>representation</span> <span style=''>Using</span> <span style=''>an</span> <span style=''>explicit</span> <span style='background-color:rgba(0, 255, 0, 0.6666666666666666);'>unification</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>based</span> <span style=''>on</span> <span style=''>semantic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>similarities</span> <span style=''>and</span> <span style=''>query</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>expansion</span> <span style=''>synonyms</span> <span style=''>and</span> <span style=''>antonymsThis</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>frequently</span> <span style=''>improves</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>precision</span> <span style=''>of</span> <span style=''>the</span> <span style=''>system</span> <span style='background-color:rgba(0, 255, 0, 0.34426229508196726);'>Employing</span> <span style=''>the</span> <span style=''>passage</span> <span style='background-color:rgba(0, 255, 0, 0.62406015037594);'>retrieval</span> <span style=''>system</span> <span style=''>achieves</span> <span style=''>a</span> <span style=''>better</span> <span style='background-color:rgba(0, 255, 0, 0.3 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Nonparametric</span> <span style=''>Nearest</span> <span style=''>Neighbor</span> <span style=''>Descent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Clustering</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Delaunay</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Triangulation</span> <br/><br/><span style=''>In</span> <span style=''>our</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>physically</span> <span style=''>inspired</span> <span style=''>in</span> <span style=''>tree</span> <span style=''>(IT)</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>clustering</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>the</span> <span style=''>series</span> <span style=''>after</span> <span style=''>it</span> <span style=''>there</span> <span style=''>is</span> <span style=''>only</span> <span style=''>one</span> <span style=''>free</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>involved</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>value</span> <span style=''>of</span> <span style=''>each</span> <span style=''>point</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>Delaunay</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Triangulation</span> <span style=''>or</span> <span style=''>its</span> <span style=''>dual</span> <span style=''>Voronoi</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>tessellation</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>process</span> <span style=''>to</span> <span style=''>compute</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>potential</span> <span style=''>values</span> <span style=''>by</span> <span style=''>the</span> <span style=''>local</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>information</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>though</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>nonparametric</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relatively</span> <span style=''>very</span> <span style=''>rough</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consequently</span> <span style=''>many</span> <span style=''>local</span> <span style=''>extreme</span> <span style=''>points</span> <span style=''>will</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>However</span> <span style=''>unlike</span> <span style=''>those</span> <span style=''>gradient</span> <span style=''>based</span> <span style=''>methods</span> <span style=''>our</span> <span style=''>IT</span> <span style=''>based</span> <span style=''>methods</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generally</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>insensitive</span> <span style=''>to</span> <span style=''>those</span> <span style=''>local</span> <span style=''>extremes</span> <span style=''>This</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>positively</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrates</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>superiority</span> <span style=''>of</span> <span style=''>these</span> <span style='backgrou ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.5238095238095238);'>Semidefinite</span> <span style=''>and</span> <span style=''>Spectral</span> <span style='background-color:rgba(255, 0, 0, 0.5238095238095238);'>Relaxations</span> <span style=''>for</span> <span style=''>Multi</span> <span style=''>Label</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Classification</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>address</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>multi</span> <span style=''>label</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>and</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>a</span> <span style=''>prior</span> <span style=''>over</span> <span style=''>the</span> <span style=''>space</span> <span style=''>of</span> <span style=''>labels</span> <span style=''>to</span> <span style=''>directly</span> <span style=''>leverage</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>performance</span> <span style=''>of</span> <span style=''>such</span> <span style=''>methods</span> <span style=''>This</span> <span style=''>prior</span> <span style=''>takes</span> <span style=''>the</span> <span style=''>form</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>quadratic</span> <span style=''>function</span> <span style=''>of</span> <span style=''>the</span> <span style=''>labels</span> <span style=''>and</span> <span style=''>permits</span> <span style=''>to</span> <span style=''>encode</span> <span style=''>both</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attractive</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>repulsive</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>relations</span> <span style=''>between</span> <span style=''>labels</span> <span style=''>We</span> <span style=''>cast</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prediction</span> <span style=''>one</span> <span style=''>aiming</span> <span style=''>at</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizing</span> <span style=''>either</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accuracies</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.5217391304347826);'>predictors</span> <span style=''>or</span> <span style=''>the</span> <span style=''>F</span> <span style=''>1</span> <span style=''>score</span> <span style=''>This</span> <span style=''>leads</span> <span style=''>to</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problem</span> <span style=''>closely</span> <span style=''>related</span> <span style=''>to</span> <span style=''>the</span> <span style=''>max</span> <span style=''>cut</span> <span style=''>problem</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>naturally</span> <span style=''>leads</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.5238095238095238);'>semidefinite</span> <span style=''>and</span> <span style=''>spectral</span> <span style='background-color:rgba(255, 0, 0, 0.5238095238095238);'>relaxations</span> <span style=''>We</span> <span style=''>show</span> <span style=''>on</span> <span style=''>sta ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Churn</span> <span style=''>analysis</span> <span style=''>using</span> <span style=''>deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoencoders</span> <br/><br/><span style=''>Customer</span> <span style=''>temporal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>behavioral</span> <span style=''>data</span> <span style=''>was</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>represented</span> <span style=''>as</span> <span style=''>images</span> <span style=''>in</span> <span style=''>order</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>churn</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>prediction</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>leveraging</span> <span style=''>deep</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>prominent</span> <span style=''>in</span> <span style=''>image</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Supervised</span> <span style=''>learning</span> <span style=''>was</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>performed</span> <span style=''>on</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>of</span> <span style=''>over</span> <span style=''>6</span> <span style=''>million</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>customers</span> <span style=''>using</span> <span style=''>deep</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convolutional</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>which</span> <span style=''>achieved</span> <span style=''>an</span> <span style=''>AUC</span> <span style=''>of</span> <span style=''>0743</span> <span style=''>on</span> <span style=''>the</span> <span style=''>test</span> <span style=''>dataset</span> <span style=''>using</span> <span style=''>no</span> <span style=''>more</span> <span style=''>than</span> <span style=''>12</span> <span style=''>temporal</span> <span style=''>features</span> <span style=''>for</span> <span style=''>each</span> <span style=''>customer</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Unsupervised</span> <span style=''>learning</span> <span style=''>was</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conducted</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>autoencoders</span> <span style=''>to</span> <span style=''>better</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>understand</span> <span style=''>the</span> <span style=''>reasons</span> <span style=''>for</span> <span style=''>customer</span> <span style=''>churn</span> <span style=''>Images</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maximally</span> <span style=''>activate</span> <span style=''>the</span> <span style=''>hidden</span> <span style=''>units</span> <span style=''>of</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>autoencoder</span> <span style=''>trained</span> <span style=''>with</span> <span style=''>churned</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>customers</span> <span style=''>reveal</span> <span style=''>ample</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>opportunities</span> <span style=''>for</span> <span style=''>action</span> <span style=''>to</span> <span style=''>be</span> <span style=''>taken</span> <span style=''>to</span> <span style=''>prevent</span> <span style=''>churn</span> <span style=''>among</span> <span style=''>strong</span> <span style=''> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	reasoning (0.05261274158911954)
# 	knowledge (0.1231209735146743)
# 	segmentation (0.06442376521116679)
# 	representation (0.12634216177523264)
# 	experimental (0.13564781675017895)
# 	processing (0.1066571224051539)
# 	different (0.2451682176091625)
# 	convolutional (0.12813171080887617)
# 	detection (0.13493199713672155)
# 	recognition (0.12956335003579098)
#
# Some Statistics words are:
# 	statistical (0.1465603190428714)
# 	distribution (0.1744765702891326)
# 	stochastic (0.1321036889332004)
# 	estimation (0.17048853439680958)
# 	algorithm (0.39282153539381853)
# 	variables (0.14556331006979062)
# 	theoretical (0.15154536390827517)
# 	dimensional (0.18494516450648055)
# 	inference (0.20638085742771686)
# 	regression (0.18344965104685942)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ba08c4d1-2265-4baf-bfdb-d675d2f5b400" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba08c4d1-2265-4baf-bfdb-d675d2f5b400")) {                    Plotly.newPlot(                        "ba08c4d1-2265-4baf-bfdb-d675d2f5b400",                        [{"x":["extensions","determine","resolution","analytical","noiseless","proposing","dimensional","algorithm","innovation","efficient","discretized","frequency","developing","extending","represent","variation","simulated","experiments","performance","independent","reconstructions","application","stochastic","analyzing","necessary","parameters","sufficient","estimator","illustrated","unstructured","conditions","abstracts","economics","restriction","considers","characterizes","consistent","factorization","retrieving","synthetic","generated","statistical","construction","convolution","variational","inferential","contributions","significantly","stationary","equivalent","nonparametric","phenomena","demonstrated","inference","modelling","dynamical","generative","distribution","constraints","challenging","classifier","employing","synthetically","conditional","insufficient","covariate","representer","predictions","regularized","demonstrate","expectation","guarantees","competing","reweighted","uncertainty","consistency","logarithmic","prediction","minimization","certainty","establish","available","regularities","applications","complexity","distributed","architectures","constancy","observation","computational","accordingly","architecture","underwater","representation","convolutions","identically","maintaining","processing","enhancement","representing","efficiently","convolutional","extremely","ensembles","distributions","achieving","comparable","popularity","increasing","community","introduced","labelling","correlated","cognitive","unsupervised","biomarkers","attracted","effective","procedure","impairment","classification","annotation","discriminative","resonance","knowledge","hippocampus","attention","alzheimers","treatment","identified","successfully","informative","extracted","typically","structures","representations","promising","extraction","diagnosis","supervised","improving","capability","different","decreasing","computation","accurately","diversity","artifacts","manipulating","occurrence","generators","principal","orientation","practical","advantages","structure","trajectory","estimation","numerically","exploiting","regression","smoothing","component","geodesics","operators","theoretical","filtering","translation","riemannian","projective","prescribed","intrinsic","adversarial","interpretation","transportation","preliminary","kantorovich","framework","calculates","especially","geometric","competition","relations","therefore","experimental","probability","constructing","outperforms","discriminator","potential","simplified","generator","approximating","confidence","reasoning","propositions","argumentation","statements","arguments","assignment","aggregated","deductive","flattening","quantitative","generalized","functions","supporting","defeasible","qualitative","uncertain","consequence","desirable","performed","formulated","connected","properties","similarity","approximates","thresholded","optimization","covariance","solutions","specifically","laplacian","minimizing","guarantee","constrained","decomposes","approaches","components","indicates","numerical","inferences","applicable","clustering","recovering","heterogeneous","approximation","multinomial","variables","depression","consisting","simultaneously","biomedical","categorical","computing","historically","including","probabilistic","protection","assumptions","connections","alternatives","appealing","providing","empirical","devel ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	confounders
# 	discriminated
# 	integrality
# 	statisticians
# 	hermitian
# 	ingenious
# 	bernsteins
# 	statistician
# 	judiciously
# 	reassignment
# 	econometrics
# 	sociology
# 	marginalize
# 	conjugacy
# 	magnetoencephalography
# 	reversible
# 	invertibility
# 	mitigates
# 	preconditioned
# 	psychiatric
# Some words which never appear in Statistics papers:
# 	certainty
# 	constancy
# 	underwater
# 	propositions
# 	argumentation
# 	deductive
# 	defeasible
# 	supervise
# 	unauthorized
# 	broadcasts
# 	broadcast
# 	genotypic
# 	evolvable
# 	inevitable
# 	evolvability
# 	genotypes
# 	accumulate
# 	phenomenal
# 	collision
# 	disruptions

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0766390794695876e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7441666666666666
